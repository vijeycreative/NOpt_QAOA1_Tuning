# %%
import gzip
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Function to save a dictionary to a gzip file
def save_dict_gzip(data_dict, filename):
    with gzip.open(filename, 'wb') as f:
        pickle.dump(data_dict, f, protocol=pickle.HIGHEST_PROTOCOL)

# Function to load a dictionary from a gzip file
def load_dict_gzip(filename):
    with gzip.open(filename, 'rb') as f:
        data_dict = pickle.load(f)
    return data_dict

# %%
num_1st_global_d2 = load_dict_gzip('num_1st_global_d2_fields.pkl.gz')
num_1st_global_d3 = load_dict_gzip('num_1st_global_d3_fields.pkl.gz')
num_1st_global_d4 = load_dict_gzip('num_1st_global_d4_fields.pkl.gz')
num_1st_global_d5 = load_dict_gzip('num_1st_global_d5_fields.pkl.gz')
num_1st_global_d6 = load_dict_gzip('num_1st_global_d6_fields.pkl.gz')
num_1st_global_d7 = load_dict_gzip('num_1st_global_d7_fields.pkl.gz')
num_1st_global_d8 = load_dict_gzip('num_1st_global_d8_fields.pkl.gz')
num_1st_global_d9 = load_dict_gzip('num_1st_global_d9_fields.pkl.gz')
num_1st_global_d10 = load_dict_gzip('num_1st_global_d10_fields.pkl.gz')

num_1st_global_er_75 = load_dict_gzip('num_1st_global_er_75_fields.pkl.gz')
num_1st_global_er_85 = load_dict_gzip('num_1st_global_er_85_fields.pkl.gz')
num_1st_global_er_95 = load_dict_gzip('num_1st_global_er_95.pkl.gz')
num_1st_global_er_105 = load_dict_gzip('num_1st_global_er_105.pkl.gz')
num_1st_global_er_115 = load_dict_gzip('num_1st_global_er_115.pkl.gz')
num_1st_global_er_129 = load_dict_gzip('num_1st_global_er_129.pkl.gz')

num_1st_global_er = {**num_1st_global_er_75, **num_1st_global_er_85, **num_1st_global_er_95, 
                     **num_1st_global_er_105, **num_1st_global_er_115, **num_1st_global_er_129}

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import numpy as np

# Prepare data for plotting
def prepare_data(data_dict):
    keys = list(data_dict.keys())
    values = list(data_dict.values())
    values = [1 - (i / 100) for i in values]
    return keys, values

# Prepare data for all dictionaries (Replace these with your actual dictionaries)
num_1st_global_d2_keys, num_1st_global_d2_values = prepare_data(num_1st_global_d2)
num_1st_global_d3_keys, num_1st_global_d3_values = prepare_data(num_1st_global_d3)
num_1st_global_d4_keys, num_1st_global_d4_values = prepare_data(num_1st_global_d4)
num_1st_global_d5_keys, num_1st_global_d5_values = prepare_data(num_1st_global_d5)
num_1st_global_d6_keys, num_1st_global_d6_values = prepare_data(num_1st_global_d6)
num_1st_global_d7_keys, num_1st_global_d7_values = prepare_data(num_1st_global_d7)
num_1st_global_d8_keys, num_1st_global_d8_values = prepare_data(num_1st_global_d8)
num_1st_global_d9_keys, num_1st_global_d9_values = prepare_data(num_1st_global_d9)
num_1st_global_d10_keys, num_1st_global_d10_values = prepare_data(num_1st_global_d10)
num_1st_global_er_keys , num_1st_global_er_values = prepare_data(num_1st_global_er)

# Define the color palette
#colors = ["#D98880", "#6BF178", "#FF6392", "#F0B27A", "#8E4162", "#AF7AC5", "#35A7FF", "#2F4858", "#F26419"]
colors = sns.color_palette("muted", 10)

# Creating the main plot with square size and grid
fig, ax = plt.subplots(figsize=(5, 3))  # Adjust the figure size for better proportions

# Plotting the lines for all dictionaries
ax.plot(num_1st_global_d2_keys, num_1st_global_d2_values, label="2", color=colors[0], linewidth=2)
ax.plot(num_1st_global_d3_keys, num_1st_global_d3_values, label="3", color=colors[1], linewidth=2)
ax.plot(num_1st_global_d4_keys, num_1st_global_d4_values, label="4", color=colors[2], linewidth=2)
ax.plot(num_1st_global_d5_keys, num_1st_global_d5_values, label="5", color=colors[3], linewidth=2)
ax.plot(num_1st_global_d6_keys, num_1st_global_d6_values, label="6", color=colors[4], linewidth=2)
ax.plot(num_1st_global_d7_keys, num_1st_global_d7_values, label="7", color=colors[5], linewidth=2)
ax.plot(num_1st_global_d8_keys, num_1st_global_d8_values, label="8", color=colors[6], linewidth=2)
ax.plot(num_1st_global_d9_keys, num_1st_global_d9_values, label="9", color=colors[7], linewidth=2)
ax.plot(num_1st_global_d10_keys, num_1st_global_d10_values, label="10", color=colors[8], linewidth=2)
ax.plot(num_1st_global_er_keys, num_1st_global_er_values, label="ER", color=colors[9], linewidth=2)

# Enhancing the aesthetics
ax.set_xlabel("Number of Nodes", fontsize=14)
ax.set_ylabel("Probability", fontsize=14)
ax.legend(loc='upper right', fontsize=12, ncol=2)
ax.grid(True, linestyle='--', alpha=0.6)  # Adding grid lines with dashed lines for aesthetics

# Set the x and y limits for the main plot
ax.set_xlim(4, 129)

# Increase font sizes for x and y ticks on the main plot
ax.tick_params(axis='both', which='major', labelsize=12)

# Creating a new Axes object below the main plot for the zoomed-in inset
# The left and width are kept similar to align the length of both plots
ax_inset = fig.add_axes([0.125, -0.325, 0.775, 0.25])  # Adjust for better positioning (left, bottom, width, height)

# Plotting the zoomed-in region in the inset
ax_inset.plot(num_1st_global_d2_keys, num_1st_global_d2_values, color=colors[0], linewidth=2.5)
ax_inset.plot(num_1st_global_d3_keys, num_1st_global_d3_values, color=colors[1], linewidth=2.5)
ax_inset.plot(num_1st_global_d4_keys, num_1st_global_d4_values, color=colors[2], linewidth=2.5)
ax_inset.plot(num_1st_global_d5_keys, num_1st_global_d5_values, color=colors[3], linewidth=2.5)
ax_inset.plot(num_1st_global_d6_keys, num_1st_global_d6_values, color=colors[4], linewidth=2.5)
ax_inset.plot(num_1st_global_d7_keys, num_1st_global_d7_values, color=colors[5], linewidth=2.5)
ax_inset.plot(num_1st_global_d8_keys, num_1st_global_d8_values, color=colors[6], linewidth=2.5)
ax_inset.plot(num_1st_global_d9_keys, num_1st_global_d9_values, color=colors[7], linewidth=2.5)
ax_inset.plot(num_1st_global_d10_keys, num_1st_global_d10_values, color=colors[8], linewidth=2.5)
ax_inset.plot(num_1st_global_er_keys, num_1st_global_er_values, color=colors[9], linewidth=2.5)

# Set the x and y limits for the inset to zoom into the lower left region
ax_inset.set_xlim(15, 128)
ax_inset.set_ylim(-0.001, 0.02)
ax_inset.grid(True, linestyle='--', alpha=0.6)  # Adding grid lines to the inset plot as well

# Increase font sizes for x and y ticks on the main plot
ax_inset.tick_params(axis='both', which='major', labelsize=12)

# Adding lines to connect the zoomed-in region
mark_inset(ax, ax_inset, loc1=1, loc2=2, fc="none", ec="0.1", linestyle="--")

# Saving the figure
plt.savefig('prob_1st_global_fields.pdf', bbox_inches='tight')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import numpy as np

# Prepare data for plotting
def prepare_data(data_dict):
    keys = list(data_dict.keys())
    values = list(data_dict.values())
    values = [1 - (i / 100) for i in values]
    return keys, values

# Prepare data for all dictionaries (Replace these with your actual dictionaries)
num_1st_global_d2_keys, num_1st_global_d2_values = prepare_data(num_1st_global_d2)
num_1st_global_d3_keys, num_1st_global_d3_values = prepare_data(num_1st_global_d3)
num_1st_global_d4_keys, num_1st_global_d4_values = prepare_data(num_1st_global_d4)
num_1st_global_d5_keys, num_1st_global_d5_values = prepare_data(num_1st_global_d5)
num_1st_global_d6_keys, num_1st_global_d6_values = prepare_data(num_1st_global_d6)
num_1st_global_d7_keys, num_1st_global_d7_values = prepare_data(num_1st_global_d7)
num_1st_global_d8_keys, num_1st_global_d8_values = prepare_data(num_1st_global_d8)
num_1st_global_d9_keys, num_1st_global_d9_values = prepare_data(num_1st_global_d9)
num_1st_global_d10_keys, num_1st_global_d10_values = prepare_data(num_1st_global_d10)
num_1st_global_er_keys , num_1st_global_er_values = prepare_data(num_1st_global_er)

# Define the color palette
#colors = ["#D98880", "#6BF178", "#FF6392", "#F0B27A", "#8E4162", "#AF7AC5", "#35A7FF", "#816E94", "#F26419", '#4B2142']
colors = sns.color_palette("husl", 11)

# Creating the main plot with square size and grid
fig, ax = plt.subplots(figsize=(4.5, 3))  # Adjust the figure size for better proportions

# Plotting the lines for all dictionaries
ax.plot(num_1st_global_d2_keys, num_1st_global_d2_values, label="2", color=colors[0], linewidth=1.5)
ax.plot(num_1st_global_d3_keys, num_1st_global_d3_values, label="3", color=colors[1], linewidth=1.5)
ax.plot(num_1st_global_d4_keys, num_1st_global_d4_values, label="4", color=colors[2], linewidth=1.5)
ax.plot(num_1st_global_d5_keys, num_1st_global_d5_values, label="5", color=colors[3], linewidth=1.5)
ax.plot(num_1st_global_d6_keys, num_1st_global_d6_values, label="6", color=colors[4], linewidth=1.5)
ax.plot(num_1st_global_d7_keys, num_1st_global_d7_values, label="7", color=colors[5], linewidth=1.5)
ax.plot(num_1st_global_d8_keys, num_1st_global_d8_values, label="8", color=colors[6], linewidth=1.5)
ax.plot(num_1st_global_d9_keys, num_1st_global_d9_values, label="9", color=colors[7], linewidth=1.5)
ax.plot(num_1st_global_d10_keys, num_1st_global_d10_values, label="10", color=colors[8], linewidth=1.5)
ax.plot(num_1st_global_er_keys, num_1st_global_er_values, label="ER", color=colors[9], linewidth=1.5)

# Enhancing the aesthetics
ax.set_xlabel("Number of Nodes", fontsize = 11)
#ax.set_ylabel("Adversarial Probability")
#ax.set_title("Ising Model with Fields")
ax.legend(
    loc='upper right', 
    fontsize=9, 
    borderaxespad=0.5
)
#ax.legend(
#    loc='upper left', 
#    bbox_to_anchor=(1.02, 1),  # Adjust (x, y) coordinates to move the legend
#    fontsize=10, 
#    borderaxespad=0
#)
ax.grid(True, linestyle='--', alpha=0.6)  # Adding grid lines with dashed lines for aesthetics

# Set the x and y limits for the main plot
ax.set_xlim(4, 129)

# Increase font sizes for x and y ticks on the main plot
ax.tick_params(axis='both', which='major', labelsize=12)

# Creating a new Axes object below the main plot for the zoomed-in inset
# The left and width are kept similar to align the length of both plots
ax_inset = fig.add_axes([0.125, -0.3125, 0.775, 0.25])  # Adjust for better positioning (left, bottom, width, height)

# Plotting the zoomed-in region in the inset
ax_inset.plot(num_1st_global_d2_keys, num_1st_global_d2_values, color=colors[0], linewidth=1.5)
ax_inset.plot(num_1st_global_d3_keys, num_1st_global_d3_values, color=colors[1], linewidth=1.5)
ax_inset.plot(num_1st_global_d4_keys, num_1st_global_d4_values, color=colors[2], linewidth=1.5)
ax_inset.plot(num_1st_global_d5_keys, num_1st_global_d5_values, color=colors[3], linewidth=1.5)
ax_inset.plot(num_1st_global_d6_keys, num_1st_global_d6_values, color=colors[4], linewidth=1.5)
ax_inset.plot(num_1st_global_d7_keys, num_1st_global_d7_values, color=colors[5], linewidth=1.5)
ax_inset.plot(num_1st_global_d8_keys, num_1st_global_d8_values, color=colors[6], linewidth=1.5)
ax_inset.plot(num_1st_global_d9_keys, num_1st_global_d9_values, color=colors[7], linewidth=1.5)
ax_inset.plot(num_1st_global_d10_keys, num_1st_global_d10_values, color=colors[8], linewidth=1.5)
ax_inset.plot(num_1st_global_er_keys, num_1st_global_er_values, color=colors[9], linewidth=1.5)

# Set the x and y limits for the inset to zoom into the lower left region
ax_inset.set_xlim(15, 128)
ax_inset.set_ylim(-0.001, 0.02)
ax_inset.grid(True, linestyle='--', alpha=0.6)  # Adding grid lines to the inset plot as well

# Increase font sizes for x and y ticks on the main plot
ax_inset.tick_params(axis='both', which='major', labelsize=12)

# Adding lines to connect the zoomed-in region
mark_inset(ax, ax_inset, loc1=1, loc2=2, fc="none", ec="0.25", linestyle="--")

# Create an additional inset for the zoomed-in region from 4 to 2
#ax_inset_2 = inset_axes(ax, width="75%", height="70%", loc='center right')

# Plotting the zoomed-in region in the second inset
#ax_inset_2.plot(num_1st_global_d2_keys, num_1st_global_d2_values, color=colors[0], linewidth=1.5)
#ax_inset_2.plot(num_1st_global_d3_keys, num_1st_global_d3_values, color=colors[1], linewidth=1.5)
#ax_inset_2.plot(num_1st_global_d4_keys, num_1st_global_d4_values, color=colors[2], linewidth=1.5)
#ax_inset_2.plot(num_1st_global_d5_keys, num_1st_global_d5_values, color=colors[3], linewidth=1.5)
#ax_inset_2.plot(num_1st_global_d6_keys, num_1st_global_d6_values, color=colors[4], linewidth=1.5)
#ax_inset_2.plot(num_1st_global_d7_keys, num_1st_global_d7_values, color=colors[5], linewidth=1.5)
#ax_inset_2.plot(num_1st_global_d8_keys, num_1st_global_d8_values, color=colors[6], linewidth=1.5)
#ax_inset_2.plot(num_1st_global_d9_keys, num_1st_global_d9_values, color=colors[7], linewidth=1.5)
#ax_inset_2.plot(num_1st_global_d10_keys, num_1st_global_d10_values, color=colors[8], linewidth=1.5)
#ax_inset_2.plot(num_1st_global_er_keys, num_1st_global_er_values, color=colors[9], linewidth=1.5)

# Set limits for the second inset
#ax_inset_2.set_xlim(4, 15)  # Adjust based on the data range you want
#ax_inset_2.set_ylim(-0.001, 0.425)  # Adjust based on the y-range for the zoomed region
#ax_inset_2.grid(True, linestyle='--', alpha=0.6)  # Adding grid lines to the inset
#
# Customize ticks for the second inset
#ax_inset_2.tick_params(axis='both', which='major', labelsize=9)

#ax_inset_2.tick_params(
#    axis='x',        # Apply changes to the x-axis
#    which='both',    # Apply to both major and minor ticks
#    top=True,        # Enable ticks on the top
#    labeltop=True,   # Show labels on the top
#    bottom=False,    # Disable ticks on the bottom
#    labelbottom=False  # Hide labels on the bottom
#)

# Add connecting lines between the main plot and the second inset
#mark_inset(ax, ax_inset_2, loc1=4, loc2=3, fc="none", ec="0.25", linestyle="dotted")

# Saving the figure
plt.savefig('prob_1st_global_fields.pdf', bbox_inches='tight')

# Show the plot
plt.show()
